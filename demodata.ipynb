# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scipy.stats as st

demodata_cases = "resources/texas_demographics_cases.csv"
demodata_deaths = "resources/texas_demographics_deaths.csv"
demodata_vaccines = "resources/texas_demographics_cases_vaccines.csv"

demodata_cases = pd.read_csv(demodata_cases)
demodata_cases.head()
# Out:
#   State Category Demo_Group Demo_Specific Estimate_type  April_2021  \
# 0    TX    Cases        age           0_9  rate_percent    2.042581
# 1    TX    Cases        age         10_19  rate_percent    4.621450
# 2    TX    Cases        age         20_29  rate_percent   19.924370
# 3    TX    Cases        age         30_39  rate_percent   21.965320
# 4    TX    Cases        age         40_49  rate_percent   19.247464
#
#     May_2021  June_2021  July_2021  August_2021  September_2021  October_2021
# 0   2.103747   2.087370   2.109844     2.385216        2.385216      2.385216
# 1   4.730021   4.795038   4.856197     5.372740        5.372740      5.372740
# 2  19.850523  19.864617  19.841767    20.400404       20.400404     20.400404
# 3  21.831431  21.782128  21.770627    21.499965       21.499965     21.499965
# 4  19.161918  19.126047  19.094784    18.604488       18.604488     18.604488

# %%
#demodata_cases_categories = demodata_cases.groupby("Category")
#type(demodata_cases_categories)
demodata_cases_cats = demodata_cases.groupby('Demo_Group')
type(demodata_cases_cats)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
#demodata_cases_categories.ngroups
demodata_cases_cats.ngroups
# Out:
# 3

# %%
demodata_cases_cats.size()
# Out:
# Demo_Group
# age               9
# gender            3
# race_ethnicity    6
# dtype: int64

# %%
demodata_cases_cats.groups
# Out:
# {'age': [0, 1, 2, 3, 4, 5, 6, 7, 8], 'gender': [9, 10, 11], 'race_ethnicity': [12, 13, 14, 15, 16, 17]}

# %%
demodata_cases_cats.first()
# Out:
#                State Category              Demo_Specific Estimate_type  \
# Demo_Group
# age               TX    Cases                        0_9  rate_percent
# gender            TX    Cases                     female  rate_percent
# race_ethnicity    TX    Cases  all_races-hispanic_latino  rate_percent
#
#                 April_2021   May_2021  June_2021  July_2021  August_2021  \
# Demo_Group
# age               2.042581   2.103747    2.08737   2.109844     2.385216
# gender           33.600000  33.950000   34.10000  34.200000    37.500000
# race_ethnicity   36.200000  35.850000   35.89000  35.800000    37.000000
#
#                 September_2021  October_2021
# Demo_Group
# age                   2.385216      2.385216
# gender               37.500000     37.500000
# race_ethnicity       37.000000     37.000000

# %%
df_age = demodata_cases_cats.get_group('age')
df_age
# Out:
#   State Category Demo_Group Demo_Specific Estimate_type  April_2021  \
# 0    TX    Cases        age           0_9  rate_percent    2.042581
# 1    TX    Cases        age         10_19  rate_percent    4.621450
# 2    TX    Cases        age         20_29  rate_percent   19.924370
# 3    TX    Cases        age         30_39  rate_percent   21.965320
# 4    TX    Cases        age         40_49  rate_percent   19.247464
# 5    TX    Cases        age         50_59  rate_percent   16.166546
# 6    TX    Cases        age         60_69  rate_percent    9.738195
# 7    TX    Cases        age         70_79  rate_percent    3.881894
# 8    TX    Cases        age      80_older  rate_percent    2.412181
#
#     May_2021  June_2021  July_2021  August_2021  September_2021  October_2021
# 0   2.103747   2.087370   2.109844     2.385216        2.385216      2.385216
# 1   4.730021   4.795038   4.856197     5.372740        5.372740      5.372740
# 2  19.850523  19.864617  19.841767    20.400404       20.400404     20.400404
# 3  21.831431  21.782128  21.770627    21.499965       21.499965     21.499965
# 4  19.161918  19.126047  19.094784    18.604488       18.604488     18.604488
# 5  16.140648  16.132766  16.116276    15.430870       15.430870     15.430870
# 6   9.787161   9.787614   9.780470     9.445817        9.445817      9.445817
# 7   3.958278   3.972168   3.980704     4.093087        4.093087      4.093087
# 8   2.436272   2.452251   2.449331     2.767411        2.767411      2.767411

# %%
age_group = demodata_cases.loc
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-70-5559513fe924> in <module>
# ----> 1 age_group = demodata_cases.loc["rate_percent"]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     893
#     894             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 895             return self._getitem_axis(maybe_callable, axis=axis)
#     896
#     897     def _is_scalar_access(self, key: Tuple):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1122         # fall thru to straight lookup
#    1123         self._validate_key(key, axis)
# -> 1124         return self._get_label(key, axis=axis)
#    1125
#    1126     def _get_slice_axis(self, slice_obj: slice, axis: int):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_label(self, label, axis)
#    1071     def _get_label(self, label, axis: int):
#    1072         # GH#5667 this will fail if the label is not present in the axis.
# -> 1073         return self.obj.xs(label, axis=axis)
#    1074
#    1075     def _handle_lowerdim_multi_index_axis0(self, tup: Tuple):
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in xs(self, key, axis, level, drop_level)
#    3737                 raise TypeError(f"Expected label or tuple of labels, got {key}") from e
#    3738         else:
# -> 3739             loc = index.get_loc(key)
#    3740
#    3741             if isinstance(loc, np.ndarray):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\range.py in get_loc(self, key, method, tolerance)
#     352                 except ValueError as err:
#     353                     raise KeyError(key) from err
# --> 354             raise KeyError(key)
#     355         return super().get_loc(key, method=method, tolerance=tolerance)
#     356
#
# KeyError: 'rate_percent'
